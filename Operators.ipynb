# %% [markdown]
# <a href="https://colab.research.google.com/github/Asim347/ai-personalized-dashboard/blob/main/Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s1 = "Asim"
s2 = "Ali"
print(s1+s2)
type(s1)
# Out:
# AsimAli
# str

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# s1         str     Asim
# s2         str     Ali

# %%
a= True
b = True
c = False

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# a          bool    True
# b          bool    True
# c          bool    False
# s1         str     Asim
# s2         str     Ali

# %%
print(a and b)
print(a and c)
print( c and a)
# Out:
# True
# False
# False

# %%
print(a or b)
print(a or c)
print(c or not(b))
# Out:
# True
# True
# False

# %% [markdown]
# ## **Comparisons**

# %%
c = 2<3
print(c)
# Out:
# True
