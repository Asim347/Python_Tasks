# %% [markdown]
# <a href="https://colab.research.google.com/github/Asim347/Python_Tasks/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
A = pd.Series([2,3,4,5],index = ['a','b','c','d'])
A.values
# Out:
# array([2, 3, 4, 5])

# %%
type(A)
# Out:
# pandas.core.series.Series

# %%
A['a']
# Out:
# np.int64(2)

# %%
A['a' : 'c']
# Out:
# a    2
# b    3
# c    4
# dtype: int64

# %%
grads_dict = {'a': 4, 'a-': 3.5, 'b': 3, 'b-' : 2.5, 'c' : 2}
grads = pd.Series(grads_dict)
grads.values
# Out:
# array([4. , 3.5, 3. , 2.5, 2. ])

# %%
grads.index
# Out:
# Index(['a', 'a-', 'b', 'b-', 'c'], dtype='object')

# %%
marks_dict = {'a': 87, 'a-': 80, 'b': 73, 'b-' : 68, 'c' : 60}
marks = pd.Series(marks_dict)
marks
# Out:
# a     87
# a-    80
# b     73
# b-    68
# c     60
# dtype: int64

# %%
marks['a']
# Out:
# np.int64(87)

# %%
marks[0:2]
# Out:
# a     87
# a-    80
# dtype: int64

# %%
#Data frames
D = pd.DataFrame({'Marks':marks, "Grades": grads})
D
D.T
# Out:
#            a    a-     b    b-     c
# Marks   87.0  80.0  73.0  68.0  60.0
# Grades   4.0   3.5   3.0   2.5   2.0

# %%
D.values
# Out:
# array([[87. ,  4. ],
#        [80. ,  3.5],
#        [73. ,  3. ],
#        [68. ,  2.5],
#        [60. ,  2. ]])

# %%
D.values[3,1]
# Out:
# np.float64(2.5)

# %%
D.columns
# Out:
# Index(['Marks', 'Grades'], dtype='object')

# %%
D['ScaleMarks']  = 100*(D['Marks']/90)
D
# Out:
#     Marks  Grades  ScaleMarks
# a      87     4.0   96.666667
# a-     80     3.5   88.888889
# b      73     3.0   81.111111
# b-     68     2.5   75.555556
# c      60     2.0   66.666667

# %%
D
# Out:
#     Marks  Grades
# a      87     4.0
# a-     80     3.5
# b      73     3.0
# b-     68     2.5
# c      60     2.0

# %%
G = D[D['Marks']> 70]
G
# Out:
#     Marks  Grades
# a      87     4.0
# a-     80     3.5
# b      73     3.0

# %%
A = pd.DataFrame([{'a':2, 'b':3}, {'b': 2, 'c':4}])
A
# Out:
#      a  b    c
# 0  2.0  3  NaN
# 1  NaN  2  4.0

# %%
A.fillna(0)
# Out:
#      a  b    c
# 0  2.0  3  0.0
# 1  0.0  2  4.0

# %%
data = pd.Series(['a','b','c'],index=[1,3,5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: object

# %%
data[1]
# Out:
# 'a'

# %%
data[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %%
data.loc[1:3]
# Out:
# 1    a
# 3    b
# dtype: object

# %%
data.iloc[1:3]
# Out:
# 3    b
# 5    c
# dtype: object

# %%
D.iloc[2,:]
# Out:
# Marks     73.0
# Grades     3.0
# Name: b, dtype: float64

# %%
from google.colab import files

uploaded = files.upload()  # This will open a file chooser
# Out:
#      <input type="file" id="files-156cffc5-4e5c-4fd3-a558-ff1310212ef2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-156cffc5-4e5c-4fd3-a558-ff1310212ef2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

df = pd.read_csv('4. covid_19_data.csv')  # Use the uploaded filename

# %%
df.head(10)
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 4  4/29/2020   NaN               Angola         27       2          7
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6  4/29/2020   NaN            Argentina       4285     214       1192
# 7  4/29/2020   NaN              Armenia       1932      30        900
# 8  4/29/2020   NaN              Austria      15402     580      12779
# 9  4/29/2020   NaN           Azerbaijan       1766      23       1267

# %%
df.drop(columns='State',inplace= True)

# %%
df.head()
# Out:
#         Date       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020  Afghanistan       1939      60        252
# 1  4/29/2020      Albania        766      30        455
# 2  4/29/2020      Algeria       3848     444       1702
# 3  4/29/2020      Andorra        743      42        423
# 4  4/29/2020       Angola         27       2          7

# %%
df = df.rename(columns= {'Region' : 'Country'})

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         Date       Region  Confirmed  Deaths  Recovered
# 0 2020-04-29  Afghanistan       1939      60        252
# 1 2020-04-29      Albania        766      30        455
# 2 2020-04-29      Algeria       3848     444       1702
# 3 2020-04-29      Andorra        743      42        423
# 4 2020-04-29       Angola         27       2          7

# %%
df2 = df.groupby('Country')[['Confirmed','Deaths','Recovered']].sum().reset_index()

# %%
df2
# Out:
#                 Country  Confirmed  Deaths  Recovered
# 0           Afghanistan       1939      60        252
# 1               Albania        766      30        455
# 2               Algeria       3848     444       1702
# 3               Andorra        743      42        423
# 4                Angola         27       2          7
# ..                  ...        ...     ...        ...
# 182  West Bank and Gaza        344       2         71
# 183      Western Sahara          6       0          5
# 184               Yemen          6       0          1
# 185              Zambia         97       3         54
# 186            Zimbabwe         32       4          5
#
# [187 rows x 4 columns]
