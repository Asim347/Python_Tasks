# %% [markdown]
# <a href="https://colab.research.google.com/github/Asim347/ai-personalized-dashboard/blob/main/Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to add two numbers

# Take input from user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# Calculate sum
sum = num1 + num2

# Display result
print("The sum of", num1, "and", num2, "is:", sum)
# Out:
# Enter first number: 12
# Enter second number: 12
# The sum of 12.0 and 12.0 is: 24.0
